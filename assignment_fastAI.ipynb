# %% [markdown]
# <a href="https://colab.research.google.com/github/chettkulkarni/deep_learning/blob/master/assignment_fastAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# urls=Array.from(document.querySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl')); 
	
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));

# %%
from fastai.vision import *
from fastai.metrics import error_rate
import pandas as pd

# %%
bs = 64
# bs = 16

# %%
# import requests
# import cv2
# import os
 
# from imutils import paths
# import pandas as pd
# data = pd.read_csv('https://raw.githubusercontent.com/chettkulkarni/deep_learning/master/santa_claus.csv', sep='delimiter', header=None)
# data=data[0]
# data.to_csv('download',index=False)

# url_path = open('download').read().strip().split('\n')
# total = 0
# print(url_path)
# if not os.path.exists('santa_claus'):
#     os.mkdir('santa_claus')
# image_path = 'santa_claus'
 
# for url in url_path:
#     try:
#         req = requests.get(url, timeout=60)
 
#         file_path = os.path.sep.join([image_path, '{}.jpg'.format(
#             str(total).zfill(6))]
#         )
#         file = open(file_path, 'wb')
#         file.write(req.content)
#         file.close()
 
#         print('Downloaded {}'.format(file_path))
#         total += 1
 
#     except:
#         print('Could not download {}. Downloading next file'.format(file_path))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   after removing the cwd from sys.path.

# %%
data
# Out:
# 0      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4      https://encrypted-tbn0.gstatic.com/images?q=tb...
#                              ...
# 578    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 579    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 580    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 581    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 582    https://encrypted-tbn0.gstatic.com/images?q=tb...
# Name: 0, Length: 583, dtype: object

# %%
 
# import requests
# import cv2
# import os
 
# from imutils import paths
# import pandas as pd
# data = pd.read_csv('https://raw.githubusercontent.com/chettkulkarni/deep_learning/master/santa_claus.csv', sep='delimiter', header=None)
# data=data[0]
# data.to_csv('download',index=False)

# url_path = open('download').read().strip().split('\n')
# total = 0
# print(url_path)
# if not os.path.exists('santa_claus'):
#     os.mkdir('santa_claus')
# image_path = 'santa_claus'
 
# for url in url_path:
#     try:
#         req = requests.get(url, timeout=60)
 
#         file_path = os.path.sep.join([image_path, '{}.jpg'.format(
#             str(total).zfill(6))]
#         )
#         file = open(file_path, 'wb')
#         file.write(req.content)
#         file.close()
 
#         print('Downloaded {}'.format(file_path))
#         total += 1
 
#     except:
#         print('Could not download {}. Downloading next file'.format(file_path))

# %%
# import requests
# import cv2
# import os
 
# from imutils import paths
# import pandas as pd
# data = pd.read_csv('https://raw.githubusercontent.com/chettkulkarni/deep_learning/master/krishna.csv', sep='delimiter', header=None)
# data=data[0]
# data.to_csv('download',index=False)

# url_path = open('download').read().strip().split('\n')
# total = 0
# print(url_path)
# if not os.path.exists('krishna'):
#     os.mkdir('krishna')
# image_path = 'krishna'
 
# for url in url_path:
#     try:
#         req = requests.get(url, timeout=60)
 
#         file_path = os.path.sep.join([image_path, '{}.jpg'.format(
#             str(total).zfill(6))]
#         )
#         file = open(file_path, 'wb')
#         file.write(req.content)
#         file.close()
 
#         print('Downloaded {}'.format(file_path))
#         total += 1
 
#     except:
#         print('Could not download {}. Downloading next file'.format(file_path))

# %%
fnames = get_image_files('santa_claus')

# %%
fnames[:5]
# Out:
# [PosixPath('santa_claus/000542.jpg'),
#  PosixPath('santa_claus/000413.jpg'),
#  PosixPath('santa_claus/000161.jpg'),
#  PosixPath('santa_claus/000219.jpg'),
#  PosixPath('santa_claus/000327.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'
path_img='santa_claus'

# %%
path='santa_claus'
data = (ImageList.from_folder(path) .random_split_by_pct() .label_from_folder() .transform(get_transforms(), size=224) .databunch())
path2='krishna'
data2 = (ImageList.from_folder(path2) .random_split_by_pct() .label_from_folder() .transform(get_transforms(), size=224) .databunch())
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:215: UserWarning: `random_split_by_pct` is deprecated, please use `split_by_rand_pct`.
#   warn("`random_split_by_pct` is deprecated, please use `split_by_rand_pct`.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:215: UserWarning: `random_split_by_pct` is deprecated, please use `split_by_rand_pct`.
#   warn("`random_split_by_pct` is deprecated, please use `split_by_rand_pct`.")

# %%
data=data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-dc52270f0afb> in <module>()
# ----> 1 data=data+data2
#
# TypeError: unsupported operand type(s) for +: 'ImageDataBunch' and 'ImageDataBunch'

# %%
data2.show_batch(rows=3, figsize=(7,6))

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data2.classes)
len(data2.classes),data2.c
# Out:
# ['santa_claus']
# (1, 1)

# %%
# data3=ImageList.add(data,data2)
